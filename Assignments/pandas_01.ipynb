# %% [markdown]
# # Assignment 1 — Inspecting a New Dataset
#
# **Pandas Basics · Introduction to Machine Learning · Dataset: Titanic**
#
# > Submit one notebook file named `RollNumber_Assignment1.ipynb`.
#
# ---
#
# ## Setup
#
# ```python
# import pandas as pd
# import seaborn as sns
#
# t = sns.load_dataset('titanic')
# # If the above does not work:
# # t = pd.read_csv('titanic.csv')

# %%
! pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from seaborn) (2.5.1)
# Requirement already satisfied: pandas>=1.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/anuruddhapratapsinghkushwah/Library/Python/3.14/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/anuruddhapratapsinghkushwah/Library/Python/3.14/lib/python/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/anuruddhapratapsinghkushwah/Library/Python/3.14/lib/python/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Q1
#
# #### Q1. Load the dataset into `t`. How many rows and how many columns does it have?

# %%
t = pd.read_csv("titanic.csv")
print(t.shape) # (row , column)
# print(df.columns)
# Out:
# (891, 12)

# %% [markdown]
# ### Q2
#
# #### Q2. Print all the column names. Pick any three and write in a comment what you think each one holds.

# %%
print(t.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %% [markdown]
# ### Q3
#
# #### Q3. Display the first 7 rows and the last 3 rows.

# %%
print(t.head(7)) # first 7 rows
print(t.tail(3)) # last 3 rows
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ### Q4
#
# #### Q4. Run `t.info()`. Some columns have fewer values than the total number of rows. Write down which columns those are, and how many values are missing from each.

# %%
# print(t.info())
# print(t.isnull().sum())
# print()
# print(t.isnull().sum()[t.isnull().sum()>0]) # all the null values count
print(t.isnull().sum().unique().sum()) # sum of all the null values
# Out:
# 866

# %% [markdown]
# ### Q5
#
# #### Q5. Run `t.describe()`. It shows fewer columns than `info()` listed. Write down two columns it left out, and explain why.

# %%
# print(t.info())

print(t.describe()) # these are mathematical operations and do not read String values 

# so the missing columns are of Name , Sex , Cabin , Embarked.
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Q6
#
# ### Q6. For the `class` column, answer all three questions below using a different function for each.
#
# #### Q6(a). How many different values are there?

# %%
print(t['Sex'].nunique())
print(t['Age'].nunique())
# Out:
# 2
# 88

# %% [markdown]
# #### Q6(b). What are they ?
# t['class'].unique()

# %%
print(t['Sex'].unique())
# Out:
# <StringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %% [markdown]
# #### Q6(c) How many passengers fall into each one ?

# %%
print(t['Sex'].value_counts())
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ### Q7
#
# #### Q7. Find how many passengers were male and how many were female.

# %%
print(t['Sex'].value_counts())
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ### Q8
#
# #### Q8. In `describe()`, look at the `age` column. Compare its mean with its 50% value. Which is larger, and what does that suggest about the passengers' ages?

# %%
print(t.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ### Q9
#
# #### Q9. Challenge — The `age` column has missing values. Using only `shape` and `info()`, work out what percentage of age values are missing. Write the number in a comment.

# %%
columns = t.shape[0]
print("columns : ",columns)
null_values = t['Age'].isnull().sum()
print("null_values : ",null_values)
ans = (null_values)/columns *100
print("ans : ",ans)

# ans is 19.865319865319865
# Out:
# columns :  891
# null_values :  177
# ans :  19.865319865319865

# %% [markdown]
# #### Assignment Completed
